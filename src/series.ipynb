# %%
import pandas as pd
ds=pd.Series([12,45,32,546,55])
print(ds)
# Out:
# 0     12
# 1     45
# 2     32
# 3    546
# 4     55
# dtype: int64

# %%
import matplotlib.pyplot as plt
x=[2,4,32,5,3,2,5,6,32,2,6,8,6,53,54,7,8,6,5,4,3,5,54,75,45,4,3,3,4,6,7,8,9,7,6,6,65,5,4,3,45,65,7,5,5,6,67,6,54,55]
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('histogram')
b=[0,10,20,30,70]
plt.hist(x,b)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=[11,22,33,44,55]
plt.plot(x,y)
plt.title("line graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
import pandas as pd
d1=pd.Series([11,22,33,44,55])
d2=pd.Series([5,6,7,8,9])
ds=d1+d2
print(ds)
ds1=d1/d2
print(ds1)
ds2=d1*d2
print(ds2)
# Out:
# 0    16
# 1    28
# 2    40
# 3    52
# 4    64
# dtype: int64
# 0    2.200000
# 1    3.666667
# 2    4.714286
# 3    5.500000
# 4    6.111111
# dtype: float64
# 0     55
# 1    132
# 2    231
# 3    352
# 4    495
# dtype: int64
